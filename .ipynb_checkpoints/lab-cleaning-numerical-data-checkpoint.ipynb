# %% [markdown]
# #### 1.Import the necessary libraries.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

# %%
# %matplotlib inline

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# #### 2.Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df (i.e. customer_df = pd.readcsv(""))

# %%
customer_df = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# #### 3.First, look at its main features (head, shape, info).

# %%
customer_df.head(8)
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
# 5  OC83172      Oregon              8256.297800      Yes     Basic  Bachelor
# 6  XZ87318      Oregon              5380.898636      Yes     Basic   College
# 7  CF85061     Arizona              7216.100311       No   Premium    Master
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
# 5           1/25/11         Employed      F   62902         Rural
# 6           2/24/11         Employed      F   55350      Suburban
# 7           1/18/11       Unemployed      M       0         Urban
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
# 5        Married                    69                       14
# 6        Married                    67                        0
# 7         Single                   101                        0
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
# 5                             94                          0
# 6                             13                          0
# 7                             68                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
# 5                   2   Personal Auto   Personal L3           Offer2
# 6                   9  Corporate Auto  Corporate L3           Offer1
# 7                   4  Corporate Auto  Corporate L3           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize
# 5           Web          159.383042   Two-Door Car      Medsize
# 6         Agent          321.600000  Four-Door Car      Medsize
# 7         Agent          363.029680  Four-Door Car      Medsize

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %%
customer_df.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %% [markdown]
# #### 4.Rename the columns so they follow the PE8 (snake case).

# %%
customer_df.columns = list(map(lambda x: x.lower().replace(' ','_'),list(customer_df.columns)))

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
list(customer_df.columns)
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'total_claim_amount',
#  'vehicle_class',
#  'vehicle_size']

# %%
customer_df
# Out:
#      customer       state           clv response  coverage education      e2d  \
# 0     BU79786  Washington   2763.519279       No     Basic  Bachelor  2/24/11
# 1     QZ44356     Arizona   6979.535903       No  Extended  Bachelor  1/31/11
# 2     AI49188      Nevada  12887.431650       No   Premium  Bachelor  2/19/11
# 3     WW63253  California   7645.861827       No     Basic  Bachelor  1/20/11
# 4     HB64268  Washington   2813.692575       No     Basic  Bachelor   2/3/11
# ...       ...         ...           ...      ...       ...       ...      ...
# 9129  LA72316  California  23405.987980       No     Basic  Bachelor  2/10/11
# 9130  PK87824  California   3096.511217      Yes  Extended   College  2/12/11
# 9131  TD14365  California   8163.890428       No  Extended  Bachelor   2/6/11
# 9132  UP19263  California   7524.442436       No  Extended   College   2/3/11
# 9133  Y167826  California   2611.836866       No  Extended   College  2/14/11
#
#         e_status gender  income  loc_code  m_status  mpa  mslc  mspi  noc  \
# 0       Employed      F   56274  Suburban   Married   69    32     5    0
# 1     Unemployed      F       0  Suburban    Single   94    13    42    0
# 2       Employed      F   48767  Suburban   Married  108    18    38    0
# 3     Unemployed      M       0  Suburban   Married  106    18    65    0
# 4       Employed      M   43836     Rural    Single   73    12    44    0
# ...          ...    ...     ...       ...       ...  ...   ...   ...  ...
# 9129    Employed      M   71941     Urban   Married   73    18    89    0
# 9130    Employed      F   21604  Suburban  Divorced   79    14    28    0
# 9131  Unemployed      M       0  Suburban    Single   85     9    37    3
# 9132    Employed      M   21941  Suburban   Married   96    34     3    0
# 9133  Unemployed      M       0  Suburban    Single   77     3    90    0
#
#       n_policies     policy_type        policy     rot      channel  \
# 0              1  Corporate Auto  Corporate L3  Offer1        Agent
# 1              8   Personal Auto   Personal L3  Offer3        Agent
# 2              2   Personal Auto   Personal L3  Offer1        Agent
# 3              7  Corporate Auto  Corporate L2  Offer1  Call Center
# 4              1   Personal Auto   Personal L1  Offer1        Agent
# ...          ...             ...           ...     ...          ...
# 9129           2   Personal Auto   Personal L1  Offer2          Web
# 9130           1  Corporate Auto  Corporate L3  Offer1       Branch
# 9131           2  Corporate Auto  Corporate L2  Offer1       Branch
# 9132           3   Personal Auto   Personal L2  Offer3       Branch
# 9133           1  Corporate Auto  Corporate L3  Offer4  Call Center
#
#               tca  vehicle_class vehicle_size
# 0      384.811147   Two-Door Car      Medsize
# 1     1131.464935  Four-Door Car      Medsize
# 2      566.472247   Two-Door Car      Medsize
# 3      529.881344            SUV      Medsize
# 4      138.130879  Four-Door Car      Medsize
# ...           ...            ...          ...
# 9129   198.234764  Four-Door Car      Medsize
# 9130   379.200000  Four-Door Car      Medsize
# 9131   790.784983  Four-Door Car      Medsize
# 9132   691.200000  Four-Door Car        Large
# 9133   369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %% [markdown]
# #### 5.Fix the data types of any other column/columns as you might see necessary.

# %%
customer_df.e2d = pd.to_datetime(customer_df.e2d)

# %%
customer_df.dtypes
# Out:
# customer                 object
# state                    object
# clv                     float64
# response                 object
# coverage                 object
# education                object
# e2d              datetime64[ns]
# e_status                 object
# gender                   object
# income                    int64
# loc_code                 object
# m_status                 object
# mpa                       int64
# mslc                      int64
# mspi                      int64
# noc                       int64
# n_policies                int64
# policy_type              object
# policy                   object
# rot                      object
# channel                  object
# tca                     float64
# vehicle_class            object
# vehicle_size             object
# dtype: object

# %%
def split_dataframe(df,num):
    cols=list(df)
    customer_df_num=df.copy()
    customer_df_cat=df.copy()
    for i in range(len(cols)):
        if df[cols[i]].nunique()<=num:
            customer_df_num=customer_df_num.drop(columns=cols[i], axis=1)
        else:
            customer_df_cat=customer_df_cat.drop(columns=cols[i], axis=1)
    return  customer_df_num ,customer_df_cat    
               
customer_num_df, customer_cat_df = split_dataframe(customer_df,10)

# %%
customer_num_df
# Out:
#      customer           clv        e2d  income  mpa  mslc  mspi          tca
# 0     BU79786   2763.519279 2011-02-24   56274   69    32     5   384.811147
# 1     QZ44356   6979.535903 2011-01-31       0   94    13    42  1131.464935
# 2     AI49188  12887.431650 2011-02-19   48767  108    18    38   566.472247
# 3     WW63253   7645.861827 2011-01-20       0  106    18    65   529.881344
# 4     HB64268   2813.692575 2011-02-03   43836   73    12    44   138.130879
# ...       ...           ...        ...     ...  ...   ...   ...          ...
# 9129  LA72316  23405.987980 2011-02-10   71941   73    18    89   198.234764
# 9130  PK87824   3096.511217 2011-02-12   21604   79    14    28   379.200000
# 9131  TD14365   8163.890428 2011-02-06       0   85     9    37   790.784983
# 9132  UP19263   7524.442436 2011-02-03   21941   96    34     3   691.200000
# 9133  Y167826   2611.836866 2011-02-14       0   77     3    90   369.600000
#
# [9134 rows x 8 columns]

# %%
customer_cat_df
# Out:
#            state response  coverage education    e_status gender  loc_code  \
# 0     Washington       No     Basic  Bachelor    Employed      F  Suburban
# 1        Arizona       No  Extended  Bachelor  Unemployed      F  Suburban
# 2         Nevada       No   Premium  Bachelor    Employed      F  Suburban
# 3     California       No     Basic  Bachelor  Unemployed      M  Suburban
# 4     Washington       No     Basic  Bachelor    Employed      M     Rural
# ...          ...      ...       ...       ...         ...    ...       ...
# 9129  California       No     Basic  Bachelor    Employed      M     Urban
# 9130  California      Yes  Extended   College    Employed      F  Suburban
# 9131  California       No  Extended  Bachelor  Unemployed      M  Suburban
# 9132  California       No  Extended   College    Employed      M  Suburban
# 9133  California       No  Extended   College  Unemployed      M  Suburban
#
#       m_status  noc  n_policies     policy_type        policy     rot  \
# 0      Married    0           1  Corporate Auto  Corporate L3  Offer1
# 1       Single    0           8   Personal Auto   Personal L3  Offer3
# 2      Married    0           2   Personal Auto   Personal L3  Offer1
# 3      Married    0           7  Corporate Auto  Corporate L2  Offer1
# 4       Single    0           1   Personal Auto   Personal L1  Offer1
# ...        ...  ...         ...             ...           ...     ...
# 9129   Married    0           2   Personal Auto   Personal L1  Offer2
# 9130  Divorced    0           1  Corporate Auto  Corporate L3  Offer1
# 9131    Single    3           2  Corporate Auto  Corporate L2  Offer1
# 9132   Married    0           3   Personal Auto   Personal L2  Offer3
# 9133    Single    0           1  Corporate Auto  Corporate L3  Offer4
#
#           channel  vehicle_class vehicle_size
# 0           Agent   Two-Door Car      Medsize
# 1           Agent  Four-Door Car      Medsize
# 2           Agent   Two-Door Car      Medsize
# 3     Call Center            SUV      Medsize
# 4           Agent  Four-Door Car      Medsize
# ...           ...            ...          ...
# 9129          Web  Four-Door Car      Medsize
# 9130       Branch  Four-Door Car      Medsize
# 9131       Branch  Four-Door Car      Medsize
# 9132       Branch  Four-Door Car        Large
# 9133  Call Center   Two-Door Car      Medsize
#
# [9134 rows x 16 columns]

# %%
customer_num_df.info()
customer_cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   customer  9134 non-null   object
#  1   clv       9134 non-null   float64
#  2   e2d       9134 non-null   datetime64[ns]
#  3   income    9134 non-null   int64
#  4   mpa       9134 non-null   int64
#  5   mslc      9134 non-null   int64
#  6   mspi      9134 non-null   int64
#  7   tca       9134 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 571.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          9134 non-null   object
#  1   response       9134 non-null   object
#  2   coverage       9134 non-null   object
#  3   education      9134 non-null   object
#  4   e_status       9134 non-null   object
#  5   gender         9134 non-null   object
#  6   loc_code       9134 non-null   object
#  7   m_status       9134 non-null   object
#  8   noc            9134 non-null   int64
#  9   n_policies     9134 non-null   int64
#  10  policy_type    9134 non-null   object
#  11  policy         9134 non-null   object
#  12  rot            9134 non-null   object
#  13  channel        9134 non-null   object
#  14  vehicle_class  9134 non-null   object
#  15  vehicle_size   9134 non-null   object
# dtypes: int64(2), object(14)
# memory usage: 1.1+ MB

# %% [markdown]
# we see the customer_id is not numerical nor categorical so we just delete it from our cat data
# effective day is also not numercial is date so i rempve it from numerical data as well

# %%
customer_num_df=customer_num_df.drop('e2d',axis=1)

# %%
customer_num_df=customer_num_df.drop('customer',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ELNAZ~1.ALL\AppData\Local\Temp/ipykernel_24956/2949920388.py in <module>
# ----> 1 customer_num_df=customer_num_df.drop('customer',axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['customer'] not found in axis"

# %% [markdown]
# #### 6.Plot a correlation matrix, and comment on what you observe.

# %%
corr_matrix=customer_num_df.corr()
fig, ax = plt.subplots(figsize=(6, 6))
ax = sns.heatmap(corr_matrix ,annot=True,cmap="rocket_r")

# %% [markdown]
# we have a high correlation between monthly_premiuom_auto with income

# %% [markdown]
# #### 7.Plot every continuous variable. Comment what you can see in the plots.

# %%
def plot_num(df):
    col=list(df.columns)
    fig,ax=plt.subplots(int(np.ceil(len(col)/3)),3 ,figsize=(20,10))
    j=0
    k=0
    for i in range(len(col)):
        sns.histplot(x =df[col[i]], data = df, ax=ax[j,k],bins = 50)
        k=k+1
        if k>=3:
            j=j+1
            k=0
            
plot_num(customer_num_df)

# %% [markdown]
# ###### customer life time value are left skewed
# ###### income we have more than 2000 customer with income of 0 so which cause that we can't see the other values in this digram properly
# ###### monthly premium auto is left skewed
# ###### month_since_last_date_claim  and months_since_policy_inception are seems to be normal
# ###### number of total claim_amount also is little left skewed
# ###### we would better to see outliers with box_plot

# %%
def plot_cat(df):
    col=list(df.columns)
    fig,ax=plt.subplots(int(np.ceil(len(col)/2)),2 ,figsize=(15,25))
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.5)
    j=0
    k=0
    for i in range(len(col)):
        chart=sns.countplot(x=df[col[i]],data=df,ax=ax[j,k])
        chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
        k=k+1
        if k>=2:
            j=j+1
            k=0
plot_cat(customer_cat_df)

# %% [markdown]
# ###### in categorical data most of the frequency of the most of them are not same as each other

# %% [markdown]
# #### Check all columns for NaN values. Decide what (if anything) you will need to do with them

# %%
customer_df.isna().sum()
d=customer_df[customer_df != '']==True
display(d.nunique())
# Out:
# customer         1
# state            1
# clv              1
# response         1
# coverage         1
# education        1
# e2d              1
# e_status         1
# gender           1
# income           1
# loc_code         1
# m_status         1
# mpa              1
# mslc             2
# mspi             2
# noc              2
# n_policies       2
# policy_type      1
# policy           1
# rot              1
# channel          1
# tca              1
# vehicle_class    1
# vehicle_size     1
# dtype: int64
